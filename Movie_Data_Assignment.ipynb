# %% [markdown]
# # **Movie Dataset Python Assignment**

# %% [markdown]
# ### **Question 1**
# Dataset (`movie.csv`) ko pandas mein load karein aur uske pehle 5 rows display karein.

# %%
import pandas as pd
data = pd.read_csv("movie.csv")
data.head()
# Out:
#                Series_Title Released_Year Certificate  Runtime  \
# 0  The Shawshank Redemption          1994           A  142 min
# 1             The Godfather          1972           A  175 min
# 2           The Dark Knight          2008          UA  152 min
# 3    The Godfather: Part II          1974           A  202 min
# 4              12 Angry Men          1957           U   96 min
#
#                   Genre  IMDB_Rating  Meta_score              Director  \
# 0                 Drama          9.3        80.0        Frank Darabont
# 1          Crime, Drama          9.2       100.0  Francis Ford Coppola
# 2  Action, Crime, Drama          9.0        84.0     Christopher Nolan
# 3          Crime, Drama          9.0        90.0  Francis Ford Coppola
# 4          Crime, Drama          9.0        96.0          Sidney Lumet
#
#             Star1  No_of_Votes        Gross
# 0     Tim Robbins      2343110   28341469.0
# 1   Marlon Brando      1620367  134966411.0
# 2  Christian Bale      2303232  534858444.0
# 3       Al Pacino      1129952   57300000.0
# 4     Henry Fonda       689845    4360000.0

# %% [markdown]
# ### **Question 2**
# Dataset ka total shape (rows aur columns count) check karke print karein.

# %%
print(data.shape)
# Out:
# (1000, 11)

# %% [markdown]
# ### **Question 3**
# Check karein ki kis kis column mein missing values (null values) hain aur unka exact count kya hai.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Series_Title   1000 non-null   object
#  1   Released_Year  1000 non-null   object
#  2   Certificate    899 non-null    object
#  3   Runtime        1000 non-null   object
#  4   Genre          1000 non-null   object
#  5   IMDB_Rating    1000 non-null   float64
#  6   Meta_score     843 non-null    float64
#  7   Director       1000 non-null   object
#  8   Star1          1000 non-null   object
#  9   No_of_Votes    1000 non-null   int64
#  10  Gross          831 non-null    float64
# dtypes: float64(3), int64(1), object(7)
# memory usage: 86.1+ KB

# %%
data.isna().sum()
# Out:
# Series_Title       0
# Released_Year      0
# Certificate      101
# Runtime            0
# Genre              0
# IMDB_Rating        0
# Meta_score       157
# Director           0
# Star1              0
# No_of_Votes        0
# Gross            169
# dtype: int64

# %% [markdown]
# ### **Question 4**
# Which movies were released after the year 2000? (Year 2000 ke baad release hone wali movies filter karein).

# %%
data.columns
# Out:
# Index(['Series_Title', 'Released_Year', 'Certificate', 'Runtime', 'Genre',
#        'IMDB_Rating', 'Meta_score', 'Director', 'Star1', 'No_of_Votes',
#        'Gross'],
#       dtype='object')

# %%
data[data['Released_Year'] == 'PG']
data.drop(966,inplace=True)

# %%
data[data['Released_Year'] == 'PG']
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Meta_score, Director, Star1, No_of_Votes, Gross]
# Index: []

# %%
data['Released_Year'].head()
# Out:
# 0    1994
# 1    1972
# 2    2008
# 3    1974
# 4    1957
# Name: Released_Year, dtype: object

# %%
data['Released_Year'] = data['Released_Year'].astype(int)

# %%
data = data[data["Released_Year"] > 2000]
data['Series_Title']
# Out:
# 2                                        The Dark Knight
# 5          The Lord of the Rings: The Return of the King
# 8                                              Inception
# 10     The Lord of the Rings: The Fellowship of the Ring
# 13                 The Lord of the Rings: The Two Towers
#                              ...
# 947                Harry Potter and the Sorcerer's Stone
# 948                                           The Others
# 949                                                 Blow
# 950                                   Enemy at the Gates
# 951                                      Minority Report
# Name: Series_Title, Length: 466, dtype: object

# %% [markdown]
# ### **Question 5**
# Which movies have an IMDB rating greater than 9? (9 se zyada IMDB rating wali movies display karein).

# %%
copy_data = data
copy_data = copy_data[copy_data['IMDB_Rating'] > 9]
copy_data['Series_Title'].sum() #0 moview have greater then 9 rating
# Out:
# 0

# %% [markdown]
# ### **Question 6**
# How many movies are there for each genre? (Har genre ki total kitni movies hain, count nikalye).

# %%
data.Genre.value_counts()
# Out:
# Genre
# Drama                           40
# Action, Crime, Drama            20
# Animation, Adventure, Comedy    19
# Drama, Romance                  19
# Comedy, Drama                   17
#                                 ..
# Adventure, Comedy, Fantasy       1
# Action, Adventure, Mystery       1
# Action, Adventure, Family        1
# Drama, Horror, Sci-Fi            1
# Action, Crime, Mystery           1
# Name: count, Length: 117, dtype: int64

# %% [markdown]
# ### **Question 7**
# Which movies were directed by Christopher Nolan? (Christopher Nolan ki directed saari movies nikalye).

# %%
c_data= data[data.Director == 'Christopher Nolan']
c_data.sample(5)
# Out:
#               Series_Title  Released_Year Certificate  Runtime  \
# 36            The Prestige           2006           U  130 min
# 573                Dunkirk           2017          UA  106 min
# 63   The Dark Knight Rises           2012          UA  164 min
# 155          Batman Begins           2005          UA  140 min
# 21            Interstellar           2014          UA  169 min
#
#                         Genre  IMDB_Rating  Meta_score           Director  \
# 36     Drama, Mystery, Sci-Fi          8.5        66.0  Christopher Nolan
# 573    Action, Drama, History          7.8        94.0  Christopher Nolan
# 63          Action, Adventure          8.4        78.0  Christopher Nolan
# 155         Action, Adventure          8.2        70.0  Christopher Nolan
# 21   Adventure, Drama, Sci-Fi          8.6        74.0  Christopher Nolan
#
#                    Star1  No_of_Votes        Gross
# 36        Christian Bale      1190259   53089891.0
# 573      Fionn Whitehead       555092  188373161.0
# 63        Christian Bale      1516346  448139099.0
# 155       Christian Bale      1308302  206852432.0
# 21   Matthew McConaughey      1512360  188020017.0

# %% [markdown]
# ### **Question 8**
# Which movies have 'Drama' mentioned in their genre? ('Drama' genre wali movies ko filter karein).

# %%
d_data = data[data.Genre == 'Drama']
d_data.sample(5)
# Out:
#               Series_Title  Released_Year Certificate  Runtime  Genre  \
# 370         Vozvrashchenie           2003         NaN  110 min  Drama
# 154                  Black           2005           U  122 min  Drama
# 619  Auf der anderen Seite           2007         NaN  122 min  Drama
# 225            Gran Torino           2008           R  116 min  Drama
# 20         Soorarai Pottru           2020           U  153 min  Drama
#
#      IMDB_Rating  Meta_score               Director             Star1  \
# 370          8.0        82.0     Andrey Zvyagintsev    Vladimir Garin
# 154          8.2         NaN  Sanjay Leela Bhansali  Amitabh Bachchan
# 619          7.8        85.0             Fatih Akin       Baki Davrak
# 225          8.1        72.0         Clint Eastwood    Clint Eastwood
# 20           8.6         NaN          Sudha Kongara            Suriya
#
#      No_of_Votes        Gross
# 370        42399     502028.0
# 154        33354     733094.0
# 619        30827     741283.0
# 225       720450  148095302.0
# 20         54995          NaN

# %% [markdown]
# ### **Question 9**
# How can we sort all movies by IMDB rating in descending order? (Movies ko highest se lowest rating ke mutabiq sort karein).

# %%
i_data = data.sort_values(ascending=False, by='IMDB_Rating')
i_data.head(7)
# Out:
#                                          Series_Title  Released_Year  \
# 2                                     The Dark Knight           2008
# 5       The Lord of the Rings: The Return of the King           2003
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
# 8                                           Inception           2010
# 13              The Lord of the Rings: The Two Towers           2002
# 22                                     Cidade de Deus           2002
# 23                      Sen to Chihiro no kamikakushi           2001
#
#    Certificate  Runtime                         Genre  IMDB_Rating  \
# 2           UA  152 min          Action, Crime, Drama          9.0
# 5            U  201 min      Action, Adventure, Drama          8.9
# 10           U  178 min      Action, Adventure, Drama          8.8
# 8           UA  148 min     Action, Adventure, Sci-Fi          8.8
# 13          UA  179 min      Action, Adventure, Drama          8.7
# 22           A  130 min                  Crime, Drama          8.6
# 23           U  125 min  Animation, Adventure, Family          8.6
#
#     Meta_score            Director              Star1  No_of_Votes  \
# 2         84.0   Christopher Nolan     Christian Bale      2303232
# 5         94.0       Peter Jackson        Elijah Wood      1642758
# 10        92.0       Peter Jackson        Elijah Wood      1661481
# 8         74.0   Christopher Nolan  Leonardo DiCaprio      2067042
# 13        87.0       Peter Jackson        Elijah Wood      1485555
# 22        79.0  Fernando Meirelles         Kátia Lund       699256
# 23        96.0      Hayao Miyazaki      Daveigh Chase       651376
#
#           Gross
# 2   534858444.0
# 5   377845905.0
# 10  315544750.0
# 8   292576195.0
# 13  342551365.0
# 22    7563397.0
# 23   10055859.0

# %% [markdown]
# ### **Question 10**
# How can we sort all movies by the number of votes they received? (No_of_Votes ke mutabiq descending order mein sort karein).

# %%
v_data = data.sort_values(ascending=False, by='No_of_Votes')
v_data.head(7)
# Out:
#                                          Series_Title  Released_Year  \
# 2                                     The Dark Knight           2008
# 8                                           Inception           2010
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
# 5       The Lord of the Rings: The Return of the King           2003
# 63                              The Dark Knight Rises           2012
# 21                                       Interstellar           2014
# 13              The Lord of the Rings: The Two Towers           2002
#
#    Certificate  Runtime                      Genre  IMDB_Rating  Meta_score  \
# 2           UA  152 min       Action, Crime, Drama          9.0        84.0
# 8           UA  148 min  Action, Adventure, Sci-Fi          8.8        74.0
# 10           U  178 min   Action, Adventure, Drama          8.8        92.0
# 5            U  201 min   Action, Adventure, Drama          8.9        94.0
# 63          UA  164 min          Action, Adventure          8.4        78.0
# 21          UA  169 min   Adventure, Drama, Sci-Fi          8.6        74.0
# 13          UA  179 min   Action, Adventure, Drama          8.7        87.0
#
#              Director                Star1  No_of_Votes        Gross
# 2   Christopher Nolan       Christian Bale      2303232  534858444.0
# 8   Christopher Nolan    Leonardo DiCaprio      2067042  292576195.0
# 10      Peter Jackson          Elijah Wood      1661481  315544750.0
# 5       Peter Jackson          Elijah Wood      1642758  377845905.0
# 63  Christopher Nolan       Christian Bale      1516346  448139099.0
# 21  Christopher Nolan  Matthew McConaughey      1512360  188020017.0
# 13      Peter Jackson          Elijah Wood      1485555  342551365.0

# %% [markdown]
# ### **Question 11**
# Which movie has the longest runtime? (Sabse lambi movie ka naam aur runtime minutes mein nikalye).

# %%
data.Runtime
# Out:
# 2      152 min
# 5      201 min
# 8      148 min
# 10     178 min
# 13     179 min
#         ...
# 947    152 min
# 948    101 min
# 949    124 min
# 950    131 min
# 951    145 min
# Name: Runtime, Length: 466, dtype: object

# %%
data['Runtime'] = data.Runtime.str.split(' ').str[0]
data['Runtime'] = data['Runtime'].astype(int)

# %%
data = data.sort_values(ascending=False, by='Runtime')
highest_runtime = data.head(1)
highest_runtime
# Out:
#            Series_Title  Released_Year Certificate  Runtime  \
# 140  Gangs of Wasseypur           2012           A      321
#
#                      Genre  IMDB_Rating  Meta_score        Director  \
# 140  Action, Comedy, Crime          8.2        89.0  Anurag Kashyap
#
#               Star1  No_of_Votes  Gross
# 140  Manoj Bajpayee        82365    NaN

# %% [markdown]
# ### **Question 12**
# Which movies have Leonardo DiCaprio listed as the first star (Star1)?

# %%
data.head(7)
m_data = data[data['Star1'] == 'Leonardo DiCaprio']
m_data
# Out:
#                          Series_Title  Released_Year Certificate  Runtime  \
# 147           The Wolf of Wall Street           2013           A      180
# 879  Once Upon a Time... in Hollywood           2019           A      161
# 343                      The Revenant           2015           A      156
# 37                       The Departed           2006           A      151
# 8                           Inception           2010          UA      148
# 361                     Blood Diamond           2006           A      143
# 243               Catch Me If You Can           2002           A      141
# 145                    Shutter Island           2010           A      138
#
#                           Genre  IMDB_Rating  Meta_score  \
# 147     Biography, Crime, Drama          8.2        75.0
# 879               Comedy, Drama          7.6        83.0
# 343    Action, Adventure, Drama          8.0        76.0
# 37       Crime, Drama, Thriller          8.5        85.0
# 8     Action, Adventure, Sci-Fi          8.8        74.0
# 361  Adventure, Drama, Thriller          8.0        64.0
# 243     Biography, Crime, Drama          8.1        75.0
# 145           Mystery, Thriller          8.2        63.0
#
#                   Director              Star1  No_of_Votes        Gross
# 147        Martin Scorsese  Leonardo DiCaprio      1187498  116900694.0
# 879      Quentin Tarantino  Leonardo DiCaprio       551309  142502728.0
# 343  Alejandro G. Iñárritu  Leonardo DiCaprio       705589  183637894.0
# 37         Martin Scorsese  Leonardo DiCaprio      1189773  132384315.0
# 8        Christopher Nolan  Leonardo DiCaprio      2067042  292576195.0
# 361           Edward Zwick  Leonardo DiCaprio       499439   57366262.0
# 243       Steven Spielberg  Leonardo DiCaprio       832846  164615351.0
# 145        Martin Scorsese  Leonardo DiCaprio      1129894  128012934.0

# %% [markdown]
# ### **Question 13**
# What is the average IMDB rating of all movies? (Saari movies ki average rating calculate karein).

# %%
data.IMDB_Rating.mean()
# Out:
# np.float64(7.913090128755365)

# %% [markdown]
# ### **Question 14**
# Dataset ka poora statistical summary (`describe()` function) display karein.

# %%
data.describe()
# Out:
#        Released_Year     Runtime  IMDB_Rating  Meta_score   No_of_Votes  \
# count     466.000000  466.000000   466.000000  400.000000  4.660000e+02
# mean     2010.152361  125.950644     7.913090   75.710000  3.263038e+05
# std         5.495293   25.161409     0.259984   12.002961  3.330308e+05
# min      2001.000000   71.000000     7.600000   28.000000  2.519800e+04
# 25%      2006.000000  108.000000     7.700000   69.000000  6.646025e+04
# 50%      2010.000000  123.000000     7.900000   77.000000  2.133105e+05
# 75%      2015.000000  139.000000     8.100000   84.000000  4.894182e+05
# max      2020.000000  321.000000     9.000000  100.000000  2.303232e+06
#
#               Gross
# count  4.140000e+02
# mean   8.797826e+07
# std    1.329703e+08
# min    1.305000e+03
# 25%    2.948574e+06
# 50%    2.965676e+07
# 75%    1.268788e+08
# max    9.366622e+08

# %% [markdown]
# ### **Question 15**
# 'Runtime' column se 'min' text ko hata kar use proper integer (numeric) data type mein convert karein.

# %% [markdown]
# ### Ans) There is no `min` text in rumtime coloumn

# %% [markdown]
# ### **Question 16**
# 'Gross' column mein jo missing values (NaN) hain, unko pooray column ke median value se fill (impute) karein.

# %%
data.Gross.fillna(data.Gross.median(), inplace=True)
data.isna().sum()
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3632\3859409469.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   data.Gross.fillna(data.Gross.median(), inplace=True)
# Series_Title      0
# Released_Year     0
# Certificate      35
# Runtime           0
# Genre             0
# IMDB_Rating       0
# Meta_score       66
# Director          0
# Star1             0
# No_of_Votes       0
# Gross             0
# dtype: int64

# %% [markdown]
# ### **Question 17**
# Har 'Certificate' category mein total kitni movies hain? (Value counts nikalye).

# %%
data.Certificate.value_counts()
# Out:
# Certificate
# UA         130
# R           89
# U           84
# A           79
# PG-13       35
# PG           7
# Unrated      1
# TV-14        1
# 16           1
# TV-PG        1
# TV-MA        1
# U/A          1
# G            1
# Name: count, dtype: int64

# %% [markdown]
# ### **Question 18**
# 'IMDB_Rating' aur 'Meta_score' ke darmiyan correlation coefficient maloom karein.

# %%
corr = data['IMDB_Rating'].corr(data['Meta_score'])
corr #coor is
# Out:
# np.float64(0.23629855269087893)

# %% [markdown]
# ### **Question 19**
# Ek naya column banayein 'Rating_100_Scale' jisme 'IMDB_Rating' ko 10 se multiply kiya gaya ho.

# %%
data['Rating_100_Scale'] = data.IMDB_Rating*10
data.head()
# Out:
#                                       Series_Title  Released_Year Certificate  \
# 140                             Gangs of Wasseypur           2012           A
# 247              Lagaan: Once Upon a Time in India           2001           U
# 156                         Swades: We, the People           2004           U
# 484                                   The Irishman           2019           R
# 5    The Lord of the Rings: The Return of the King           2003           U
#
#      Runtime                      Genre  IMDB_Rating  Meta_score  \
# 140      321      Action, Comedy, Crime          8.2        89.0
# 247      224  Adventure, Drama, Musical          8.1        84.0
# 156      210                      Drama          8.2         NaN
# 484      209    Biography, Crime, Drama          7.9        94.0
# 5        201   Action, Adventure, Drama          8.9        94.0
#
#                Director           Star1  No_of_Votes        Gross  \
# 140      Anurag Kashyap  Manoj Bajpayee        82365   29656758.0
# 247  Ashutosh Gowariker      Aamir Khan       105036      70147.0
# 156  Ashutosh Gowariker  Shah Rukh Khan        83005    1223240.0
# 484     Martin Scorsese  Robert De Niro       324720    7000000.0
# 5         Peter Jackson     Elijah Wood      1642758  377845905.0
#
#      Rating_100_Scale
# 140              82.0
# 247              81.0
# 156              82.0
# 484              79.0
# 5                89.0

# %% [markdown]
# ### **Question 20**
# Year 1990 se 2000 (both inclusive) ke darmiyan release hone wali movies ki total count aur list nikaleyin.

# %%
data[(data['Released_Year'] >= 1990) & (data['Released_Year'] <= 2000)]  #there is no movie which is released between 1990 - 2000
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Meta_score, Director, Star1, No_of_Votes, Gross, Rating_100_Scale]
# Index: []

# %% [markdown]
# ### **Question 21**
# (Visualization) IMDB_Rating ka distribution dekhne ke liye ek neat Histogram plot karein.

# %%
import seaborn as sns
sns.histplot(data= data.IMDB_Rating, kde=True, )
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Count'>

# %% [markdown]
# ### **Question 22**
# (Visualization) Top 10 Directors aur unki total movies ka ek attractive Bar Chart banayein.

# %%
director_counts =data['Director'].value_counts().head(10)
sns.barplot(
    x= director_counts.values,
    y=director_counts.index
)
# Out:
# <Axes: ylabel='Director'>

# %% [markdown]
# ### **Question 23**
# (Visualization) IMDB_Rating aur Gross revenue ke darmiyan ek Scatter Plot banayein taake dono ka relation dikhe.

# %%
sns.scatterplot(
    x=data.IMDB_Rating,
    y=data.Gross
)
# Out:
# <Axes: xlabel='IMDB_Rating', ylabel='Gross'>

# %% [markdown]
# ### **Question 24**
# (Visualization) Genres ka count dekhne ke liye top 5 genres ka ek clean Pie Chart banayein.

# %%
import matplotlib.pyplot as plt
data_genre = data['Genre'].value_counts().head(5)
plt.pie(x=data_genre.values, labels=data_genre.index,autopct='%1.2f%%')
plt.show()

# %% [markdown]
# ### **Question 25**
# (Visualization) Meta_score ka distribution aur outliers check karne ke liye ek Box Plot banayein.

# %%
import seaborn as sns
sns.boxplot(data.Meta_score)
# Out:
# <Axes: ylabel='Meta_score'>

# %% [markdown]
# ### **Question 26**
# (Visualization) Dataset mein 'Certificate' wise average 'Gross' kamai ka ek Bar Plot banayein.

# %%
data_cr = data.groupby('Certificate')['Gross'].mean()
sns.barplot(
    y= data_cr.index,
    x=data_cr.values
)
# Out:
# <Axes: ylabel='Certificate'>

# %% [markdown]
# ### **Question 27**
# (Visualization) Har saal (Released_Year) kitni movies release hueen, iska ek Line Plot banayein.

# %%
data_year = data.Released_Year.value_counts()
sns.lineplot(x=data_year.index, y=data_year.values)
# Out:
# <Axes: xlabel='Released_Year'>

# %% [markdown]
# ### **Question 28**
# (Visualization) 'No_of_Votes' ke mutabiq top 5 highest voted movies ka ek Horizontal Bar Chart banayein.

# %%
#    Method 1 to find top 5 max values
mv_data = data.sort_values(ascending=False, by='No_of_Votes').set_index('No_of_Votes').Series_Title.head(5)
sns.barplot(x=mv_data.index, y=mv_data.values)
# Out:
# <Axes: xlabel='No_of_Votes'>

# %%
#    Method 3 to find top 5 max values
mv2_data =data.nlargest(5,'No_of_Votes').set_index('No_of_Votes').Series_Title
sns.barplot(x=mv2_data.index,y=mv2_data.values)
# Out:
# <Axes: xlabel='No_of_Votes'>

# %% [markdown]
# ### **Question 29**
# Har movie ke 'Genre' column ko split karke check karein ki total unique genres pure dataset mein kitne hain.

# %%
single_genre = data.Genre.str.split(", ").explode()   # explode convert all list index into new rows
unique_genre =single_genre.unique()
noug = single_genre.nunique()
print('Unique Genre List', unique_genre)
print('Number Of Unique Genre', noug)
# Out:
# Unique Genre List ['Action' 'Comedy' 'Crime' 'Adventure' 'Drama' 'Musical' 'Biography'
#  'Family' 'Sport' 'Romance' 'Fantasy' 'Sci-Fi' 'Mystery' 'Western'
#  'History' 'Thriller' 'Music' 'War' 'Animation' 'Horror']
# Number Of Unique Genre 20

# %% [markdown]
# ### **Question 30**
# Dataset ko poora clean karne ke baad safely ek nayi csv file 'cleaned_movies.csv' ke naam se save karein.

# %%
data.head()
# Out:
#                                       Series_Title  Released_Year Certificate  \
# 140                             Gangs of Wasseypur           2012           A
# 247              Lagaan: Once Upon a Time in India           2001           U
# 156                         Swades: We, the People           2004           U
# 484                                   The Irishman           2019           R
# 5    The Lord of the Rings: The Return of the King           2003           U
#
#      Runtime                      Genre  IMDB_Rating  Meta_score  \
# 140      321      Action, Comedy, Crime          8.2        89.0
# 247      224  Adventure, Drama, Musical          8.1        84.0
# 156      210                      Drama          8.2         NaN
# 484      209    Biography, Crime, Drama          7.9        94.0
# 5        201   Action, Adventure, Drama          8.9        94.0
#
#                Director           Star1  No_of_Votes        Gross  \
# 140      Anurag Kashyap  Manoj Bajpayee        82365   29656758.0
# 247  Ashutosh Gowariker      Aamir Khan       105036      70147.0
# 156  Ashutosh Gowariker  Shah Rukh Khan        83005    1223240.0
# 484     Martin Scorsese  Robert De Niro       324720    7000000.0
# 5         Peter Jackson     Elijah Wood      1642758  377845905.0
#
#      Rating_100_Scale
# 140              82.0
# 247              81.0
# 156              82.0
# 484              79.0
# 5                89.0

# %%
data.Meta_score.isna().sum()
# Out:
# np.int64(66)

# %%
data.fillna(data.Certificate.mode()[0], inplace=True)
# data.Certificate.isna().sum()
# data.fillna(data.Meta_score.astype(int).mean())
data = data[data.Meta_score != 'UA']
data['Meta_score'].isin(["UA"]).sum()
data.to_csv('cleaned_movies.csv')
# Out:
# C:\Users\HP\AppData\Local\Temp\ipykernel_3632\1076281007.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'UA' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   data.fillna(data.Certificate.mode()[0], inplace=True)

# %%
data
# Out:
#                                       Series_Title  Released_Year Certificate  \
# 140                             Gangs of Wasseypur           2012           A
# 247              Lagaan: Once Upon a Time in India           2001           U
# 484                                   The Irishman           2019           R
# 5    The Lord of the Rings: The Return of the King           2003           U
# 206                                     Kis Uykusu           2014          UA
# ..                                             ...            ...         ...
# 617                                           Once           2007           R
# 727                      What We Do in the Shadows           2014           R
# 640                   Les triplettes de Belleville           2003       PG-13
# 237                                  Before Sunset           2004           R
# 920                            The Secret of Kells           2009          UA
#
#      Runtime                         Genre  IMDB_Rating Meta_score  \
# 140      321         Action, Comedy, Crime          8.2       89.0
# 247      224     Adventure, Drama, Musical          8.1       84.0
# 484      209       Biography, Crime, Drama          7.9       94.0
# 5        201      Action, Adventure, Drama          8.9       94.0
# 206      196                         Drama          8.1       88.0
# ..       ...                           ...          ...        ...
# 617       86         Drama, Music, Romance          7.8       88.0
# 727       86                Comedy, Horror          7.7       76.0
# 640       80      Animation, Comedy, Drama          7.8       91.0
# 237       80                Drama, Romance          8.1       90.0
# 920       71  Animation, Adventure, Family          7.6       81.0
#
#                Director               Star1  No_of_Votes        Gross  \
# 140      Anurag Kashyap      Manoj Bajpayee        82365   29656758.0
# 247  Ashutosh Gowariker          Aamir Khan       105036      70147.0
# 484     Martin Scorsese      Robert De Niro       324720    7000000.0
# 5         Peter Jackson         Elijah Wood      1642758  377845905.0
# 206   Nuri Bilge Ceylan      Haluk Bilginer        46547     165520.0
# ..                  ...                 ...          ...          ...
# 617         John Carney        Glen Hansard       110656    9439923.0
# 727     Jemaine Clement       Taika Waititi       157498    3333000.0
# 640      Sylvain Chomet  Michèle Caucheteux        50622    7002255.0
# 237   Richard Linklater         Ethan Hawke       236311    5820649.0
# 920          Tomm Moore         Nora Twomey        31779     686383.0
#
#      Rating_100_Scale
# 140              82.0
# 247              81.0
# 484              79.0
# 5                89.0
# 206              81.0
# ..                ...
# 617              78.0
# 727              77.0
# 640              78.0
# 237              81.0
# 920              76.0
#
# [400 rows x 12 columns]

# %% [markdown]
# ### **Question 31**
# Kaunsi movies hain jinki 'IMDB_Rating' 8.5 se zyada hai AUR unka 'Gross' revenue 100 million (100,000,000) se zyada hai? (Dual condition filter)

# %%
data[(data.IMDB_Rating > 8.5) & (data.Gross > 100000000)].Series_Title
# Out:
# 5         The Lord of the Rings: The Return of the King
# 13                The Lord of the Rings: The Two Towers
# 10    The Lord of the Rings: The Fellowship of the Ring
# 21                                         Interstellar
# 2                                       The Dark Knight
# 8                                             Inception
# Name: Series_Title, dtype: object

# %% [markdown]
# ### **Question 32**
# Director 'Christopher Nolan' ki un movies ke naam aur release year nikalein jinka 'Runtime' 140 minutes se zyada hai.

# %%
data[(data.Director == 'Christopher Nolan') & (data.Runtime >140 )].Series_Title
# Out:
# 21             Interstellar
# 63    The Dark Knight Rises
# 2           The Dark Knight
# 8                 Inception
# Name: Series_Title, dtype: object

# %% [markdown]
# ### **Question 33**
# Aise actors (Star1) ki list nikalein jinhone 'Action' ya 'Sci-Fi' genre mein kaam kiya hai AUR unki movies ki 'IMDB_Rating' kam az kam 8.0 hai.

# %%
data['Genre'] = data['Genre'].str.split(',').str[0]

# %%
(data[(data.Genre == 'Action') | (data.Genre == 'Sci_Fi') & (data.IMDB_Rating <= 8.0)]).Star1
# Out:
# 140    Manoj Bajpayee
# 5         Elijah Wood
# 59          Joe Russo
# 13        Elijah Wood
# 10        Elijah Wood
#             ...
# 68       Choi Min-sik
# 375          Alan Mak
# 918       Naomi Watts
# 776      Stephen Chow
# 615       Liam Neeson
# Name: Star1, Length: 85, dtype: object

# %% [markdown]
# ### **Question 34**
# Year 2010 se 2020 ke darmiyan release hone wali un movies ka data filter karein jinko Certificate 'UA' ya 'A' mila hai.

# %%
(data[(data.Released_Year.between(2010,2020)) & (data.Certificate == 'UA') | (data.Certificate == 'A')]).Series_Title
# Out:
# 140         Gangs of Wasseypur
# 206                 Kis Uykusu
# 59           Avengers: Endgame
# 734             La vie d'Adèle
# 147    The Wolf of Wall Street
#                 ...
# 598           Moonrise Kingdom
# 745                    Gravity
# 615                      Taken
# 912                 Zombieland
# 138                Mandariinid
# Name: Series_Title, Length: 150, dtype: object

# %% [markdown]
# ### **Question 35**
# Dataset mein 'Meta_score' 90 se zyada aur 'IMDB_Rating' 8.5 se kam wali unique movies kaunsi hain?

# %%
((data[(data.Meta_score > 90) & (data.IMDB_Rating < 8.5)]).Series_Title).unique()
# Out:
# array(['The Irishman', 'Boyhood', 'There Will Be Blood', 'Leviafan',
#        'Manchester by the Sea', 'Marriage Story', 'Roma', 'Little Women',
#        '12 Years a Slave', 'Call Me by Your Name', 'Spotlight',
#        'La La Land', 'Amour', 'Jodaeiye Nader az Simin',
#        'Portrait de la jeune fille en feu', 'No Country for Old Men',
#        'Manbiki kazoku', 'The Social Network', "Pan's Labyrinth",
#        '4 luni, 3 saptamâni si 2 zile', 'Le scaphandre et le papillon',
#        'Ratatouille', 'The Florida Project', 'Before Midnight', 'Dunkirk',
#        'Toy Story 3', 'WALL·E', 'Inside Out', 'Gravity',
#        'Les triplettes de Belleville'], dtype=object)

# %% [markdown]
# ### **Question 36**
# (Visualization) 'Drama' aur 'Action' genres ki movies ke 'Gross' revenue ko compare karne ke liye ek Grouped Box Plot ya Violin Plot banayein.

# %%
filtere_data = data[data['Genre'].isin(['Action','Drama'])].dropna(subset=['Gross'])
sns.boxplot(filtere_data,x='Genre',y='Gross', )
# Out:
# <Axes: xlabel='Genre', ylabel='Gross'>

# %% [markdown]
# ### **Question 37**
# Har Director ki un movies ka count maloom karein jinhone 'No_of_Votes' 500,000 (5 lakh) se zyada hasil kiye hain.

# %%
(data[data.No_of_Votes >500000]).Director.value_counts()
# Out:
# Director
# Christopher Nolan    7
# Quentin Tarantino    6
# Peter Jackson        5
# Anthony Russo        4
# Martin Scorsese      3
#                     ..
# Dean DeBlois         1
# Pierre Coffin        1
# Andrew Adamson       1
# Pierre Morel         1
# Ruben Fleischer      1
# Name: count, Length: 76, dtype: int64

# %% [markdown]
# ### **Question 38**
# Un movies ke naam aur ratings batayein jinka 'Released_Year' 2000 se pehle ka hai AUR unka 'Gross' unke overall median gross se zyada hai.

# %%
fl_gross = data[data.Gross.median() > data.Gross]
fl_gross[fl_gross.Released_Year <= 2000] # There is no movie which gross median is greater then its own gross plus its release before 2000
# Out:
# Empty DataFrame
# Columns: [Series_Title, Released_Year, Certificate, Runtime, Genre, IMDB_Rating, Meta_score, Director, Star1, No_of_Votes, Gross, Rating_100_Scale]
# Index: []

# %% [markdown]
# ### **Question 39**
# Aisi movies ka data nikalein jahan 'Star1' (Main Actor) aur 'Director' dono bilkul same person hain.

# %%
data[data.Director == data.Star1]
top_5_moovi
# Out:
#                                          Series_Title  Released_Year  \
# 2                                     The Dark Knight           2008
# 5       The Lord of the Rings: The Return of the King           2003
# 8                                           Inception           2010
# 10  The Lord of the Rings: The Fellowship of the Ring           2001
# 13              The Lord of the Rings: The Two Towers           2002
#
#    Certificate  Runtime   Genre  IMDB_Rating Meta_score           Director  \
# 2           UA      152  Action          9.0       84.0  Christopher Nolan
# 5            U      201  Action          8.9       94.0      Peter Jackson
# 8           UA      148  Action          8.8       74.0  Christopher Nolan
# 10           U      178  Action          8.8       92.0      Peter Jackson
# 13          UA      179  Action          8.7       87.0      Peter Jackson
#
#                 Star1  No_of_Votes        Gross  Rating_100_Scale
# 2      Christian Bale      2303232  534858444.0              90.0
# 5         Elijah Wood      1642758  377845905.0              89.0
# 8   Leonardo DiCaprio      2067042  292576195.0              88.0
# 10        Elijah Wood      1661481  315544750.0              88.0
# 13        Elijah Wood      1485555  342551365.0              87.0

# %% [markdown]
# ### **Question 40**
# (Visualization) Top 5 highest rated movies aur unke 'Meta_score' vs 'IMDB_Rating' (scaled to 100) ka ek Side-by-Side Comparison Bar Chart banayein.

# %%
plt.figure(figsize=(12,6))
top_5_moovi = data.sort_values(ascending=False, by='IMDB_Rating' ).head()
sns.barplot(data = top_5_moovi, y='Rating_100_Scale', x='Meta_score', hue='Series_Title', saturation=100)
plt.show()
